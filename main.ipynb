# %%
file_path = './Dataset/ara_.txt'

with open(file_path, 'r', encoding='utf-8') as f:
    data = f.read()

lines = data.strip().split('\n')
sentence_pairs = [line.split('\t') for line in lines if '\t' in line]

english_sentences, arabic_sentences = zip(*sentence_pairs)

# %%
import re

def preprocess_arabic(sent):
    sent = sent.strip()
    return sent

def preprocess_english(sent):
    sent = sent.lower().strip()
    sent = re.sub(r"([?.!,¿])", r" \1 ", sent)
    sent = re.sub(r'[" "]+', " ", sent)
    sent = re.sub(r"[^a-zA-Z?.!,¿]+", " ", sent)
    sent = sent.strip()
    return sent

# Apply preprocessing
preprocessed_english = ['<start> ' + preprocess_english(s) + ' <end>' for s in english_sentences]
preprocessed_arabic = ['<start> ' + preprocess_arabic(s) + ' <end>' for s in arabic_sentences]

# %% [markdown]
# <h3>Tokenization and Padding</h3>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer_en = Tokenizer(filters='')
tokenizer_en.fit_on_texts(preprocessed_english)
tensor_en = tokenizer_en.texts_to_sequences(preprocessed_english)
tensor_en = pad_sequences(tensor_en, padding='post')

tokenizer_ar = Tokenizer(filters='')
tokenizer_ar.fit_on_texts(preprocessed_arabic)
tensor_ar = tokenizer_ar.texts_to_sequences(preprocessed_arabic)
tensor_ar = pad_sequences(tensor_ar, padding='post')


vocab_size_en = len(tokenizer_en.word_index) + 1
vocab_size_ar = len(tokenizer_ar.word_index) + 1

# %% [markdown]
# <h3>Tokenization and Padding</h3>

# %%
import keras_nlp
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


embed_dim = 128
num_heads = 2
ff_dim = 256




encoder_inputs = layers.Input(shape=(None,), dtype="int64", name="encoder_inputs")
decoder_inputs = layers.Input(shape=(None,), dtype="int64", name="decoder_inputs")


encoder_embedding = layers.Embedding(input_dim=vocab_size_ar, output_dim=embed_dim)(encoder_inputs)
decoder_embedding = layers.Embedding(input_dim=vocab_size_en, output_dim=embed_dim)(decoder_inputs)


encoder_embedding = layers.LayerNormalization()(encoder_embedding)
decoder_embedding = layers.LayerNormalization()(decoder_embedding)


transformer_decoder = keras_nlp.layers.TransformerDecoder(
    intermediate_dim=ff_dim,
    num_heads=num_heads
)


x = transformer_decoder(
    decoder_embedding,
    encoder_embedding,
    decoder_padding_mask=None,
    encoder_padding_mask=None
)

outputs = layers.Dense(vocab_size_en, activation="softmax")(x)

model = keras.Model([encoder_inputs, decoder_inputs], outputs)

# %% [markdown]
# <h3>Train the Model</h3>

# %%
from sklearn.model_selection import train_test_split

input_tensor_train, input_tensor_test, target_tensor_train, target_tensor_test = train_test_split(
    tensor_ar, tensor_en, test_size=0.1)

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])


decoder_input_data = target_tensor_train[:, :-1]
decoder_target_data = target_tensor_train[:, 1:]

model.fit(
    [input_tensor_train, decoder_input_data],
    decoder_target_data,
    batch_size=64,
    epochs=10,
    validation_split=0.1
)
# Out:
# Epoch 1/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 208ms/step - accuracy: 0.8571 - loss: 1.1273 - val_accuracy: 0.8746 - val_loss: 0.7467
# Epoch 2/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 30s 217ms/step - accuracy: 0.8818 - loss: 0.6854 - val_accuracy: 0.8878 - val_loss: 0.6575
# Epoch 3/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 241ms/step - accuracy: 0.9030 - loss: 0.5374 - val_accuracy: 0.8964 - val_loss: 0.6083
# Epoch 4/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 52s 381ms/step - accuracy: 0.9212 - loss: 0.4201 - val_accuracy: 0.8997 - val_loss: 0.5917
# Epoch 5/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 70s 517ms/step - accuracy: 0.9393 - loss: 0.3131 - val_accuracy: 0.9038 - val_loss: 0.5880
# Epoch 6/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 71s 521ms/step - accuracy: 0.9551 - loss: 0.2257 - val_accuracy: 0.9046 - val_loss: 0.6012
# Epoch 7/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 549ms/step - accuracy: 0.9701 - loss: 0.1513 - val_accuracy: 0.9076 - val_loss: 0.6187
# Epoch 8/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 46s 337ms/step - accuracy: 0.9806 - loss: 0.0998 - val_accuracy: 0.9079 - val_loss: 0.6370
# Epoch 9/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 71s 524ms/step - accuracy: 0.9882 - loss: 0.0649 - val_accuracy: 0.9070 - val_loss: 0.6590
# Epoch 10/10
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 56s 415ms/step - accuracy: 0.9922 - loss: 0.0435 - val_accuracy: 0.9082 - val_loss: 0.6751

# %% [markdown]
# <h3>Test the Model</h3>

# %%
decoder_input_test = target_tensor_test[:, :-1]
decoder_target_test = target_tensor_test[:, 1:]

loss, accuracy = model.evaluate(
    [input_tensor_test, decoder_input_test],
    decoder_target_test
)

print(f"🔍 Test Loss: {loss:.4f}")
print(f"✅ Test Accuracy (token-level): {accuracy:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9085 - loss: 0.6670
# 🔍 Test Loss: 0.6644
# ✅ Test Accuracy (token-level): 0.9097

# %%
def translate(sentence):
    sentence = preprocess_arabic(sentence)
    sentence = '<start> ' + sentence + ' <end>'
    sequence = tokenizer_ar.texts_to_sequences([sentence])
    sequence = pad_sequences(sequence, maxlen=tensor_ar.shape[1], padding='post')

    output = [tokenizer_en.word_index['<start>']]
    
    for _ in range(tensor_en.shape[1]):
        decoder_input = pad_sequences([output], maxlen=tensor_en.shape[1], padding='post')
        predictions = model.predict([sequence, decoder_input], verbose=0)
        next_token = predictions[0, len(output)-1].argmax()
        output.append(next_token)
        if tokenizer_en.index_word.get(next_token) == '<end>':
            break

    translated = [tokenizer_en.index_word.get(i, '') for i in output if i > 0]
    return ' '.join(translated).replace('<start>', '').replace('<end>', '').strip()

# %%
for arabic_sen, english_sen in zip(arabic_sentences[:1000], preprocessed_english[:1000]):
    print(f"Arabic: {arabic_sen}")
    print(f"English: {english_sen}")
    print(f"Translated: {translate(arabic_sen)}")
    print("-" * 50)
# Out:
# Arabic: مرحبًا.
# English: <start> hi . <end>
# Translated: it s get a little .
# --------------------------------------------------
# Arabic: اركض!
# English: <start> run ! <end>
# Translated: run !
# --------------------------------------------------
# Arabic: النجدة!
# English: <start> help ! <end>
# Translated: help !
# --------------------------------------------------
# Arabic: اقفز!
# English: <start> jump ! <end>
# Translated: jump !
# --------------------------------------------------
# Arabic: قف!
# English: <start> stop ! <end>
# Translated: stop !
# --------------------------------------------------
# Arabic: داوم.
# English: <start> go on . <end>
# Translated: go on .
# --------------------------------------------------
# Arabic: استمر.
# English: <start> go on . <end>
# Translated: go on .
# --------------------------------------------------
# Arabic: مرحباً.
# English: <start> hello ! <end>
# Translated: hello !
# --------------------------------------------------
# Arabic: تعجّل!
# English: <start> hurry ! <end>
# Translated: he made me a job .
# --------------------------------------------------
# Arabic: استعجل!
# English: <start> hurry ! <end>
# Translated: hurry !
# --------------------------------------------------
# Arabic: انا اري
# English: <start> i see . <end>
# Translated: i see .
# --------------------------------------------------
# Arabic: أنا فُزت!
# English: <start> i won ! <end>
# Translated: i m from your supper .
# --------------------------------------------------
# Arabic: ابتسم.
# English: <start> smile . <end>
# Translated: smile .
# --------------------------------------------------
# Arabic: في صحتك.
# English: <start> cheers ! <end>
# Translated: cheers !
# --------------------------------------------------
# Arabic: هل فهمت؟
# English: <start> got it ? <end>
# Translated: got it ?
# --------------------------------------------------
# Arabic: ركض.
# English: <start> he ran . <end>
# Translated: he ran .
# --------------------------------------------------
# Arabic: أعرف.
# English: <start> i know . <end>
# Translated: i know .
# --------------------------------------------------
# Arabic: أعلم ذلك.
# English: <start> i know . <end>
# Translated: i know .
# --------------------------------------------------
# Arabic: أنا أعلم
# English: <start> i know . <end>
# Translated: i know .
# --------------------------------------------------
# Arabic: أنا في 19
# English: <start> i m . <end>
# Translated: i m .
# --------------------------------------------------
# Arabic: أنا بخير.
# English: <start> i m ok . <end>
# Translated: i m ok .
# --------------------------------------------------
# Arabic: استمع
# English: <start> listen . <end>
# Translated: listen .
# --------------------------------------------------
# Arabic: غير معقول!
# English: <start> no way ! <end>
# Translated: no way !
# --------------------------------------------------
# Arabic: حقاً؟
# English: <start> really ? <end>
# Translated: really really is really not really !
# --------------------------------------------------
# Arabic: لماذا أنا؟
# English: <start> why me ? <end>
# Translated: why am i ?
# --------------------------------------------------
# Arabic: رائع!
# English: <start> awesome ! <end>
# Translated: terrific !
# --------------------------------------------------
# Arabic: هاتفني.
# English: <start> call me . <end>
# Translated: i m sure you for your mother .
# --------------------------------------------------
# Arabic: اتصل بي.
# English: <start> call me . <end>
# Translated: call me .
# --------------------------------------------------
# Arabic: تفضل بالدخول.
# English: <start> come in . <end>
# Translated: please come in .
# --------------------------------------------------
# Arabic: تعال إلى الداخل
# English: <start> come in . <end>
# Translated: come in .
# --------------------------------------------------
# Arabic: بالله عليك!
# English: <start> come on ! <end>
# Translated: come on !
# --------------------------------------------------
# Arabic: هيا
# English: <start> come on ! <end>
# Translated: let s get a now .
# --------------------------------------------------
# Arabic: هيّا
# English: <start> come on ! <end>
# Translated: come on !
# --------------------------------------------------
# Arabic: اخرج من هنا!
# English: <start> get out ! <end>
# Translated: get out !
# --------------------------------------------------
# Arabic: أُخرج!
# English: <start> get out ! <end>
# Translated: he has been dead for the kitchen .
# --------------------------------------------------
# Arabic: اخرج!
# English: <start> get out . <end>
# Translated: get out .
# --------------------------------------------------
# Arabic: اتركني و شأني.
# English: <start> go away . <end>
# Translated: in leave , he has alone .
# --------------------------------------------------
# Arabic: اذهب بعيداً.
# English: <start> go away . <end>
# Translated: go away .
# --------------------------------------------------
# Arabic: ارحل.
# English: <start> go away . <end>
# Translated: go away .
# --------------------------------------------------
# Arabic: مع السلامة.
# English: <start> goodbye ! <end>
# Translated: take care .
# --------------------------------------------------
# Arabic: لقد أتى.
# English: <start> he came . <end>
# Translated: he came .
# --------------------------------------------------
# Arabic: هو يجري
# English: <start> he runs . <end>
# Translated: he runs .
# --------------------------------------------------
# Arabic: ساعدني!
# English: <start> help me ! <end>
# Translated: help me !
# --------------------------------------------------
# Arabic: النجدة! ساعدني!
# English: <start> help me . <end>
# Translated: help me !
# --------------------------------------------------
# Arabic: أنا حزين.
# English: <start> i m sad . <end>
# Translated: i m sad .
# --------------------------------------------------
# Arabic: أنا أيضاً.
# English: <start> me , too . <end>
# Translated: i am !
# --------------------------------------------------
# Arabic: اخرس!
# English: <start> shut up ! <end>
# Translated: shut up !
# --------------------------------------------------
# Arabic: اصمت!
# English: <start> shut up ! <end>
# Translated: we ve played golf .
# --------------------------------------------------
# Arabic: اسكت!
# English: <start> shut up ! <end>
# Translated: shut up !
# --------------------------------------------------
# Arabic: أغلق فمك!
# English: <start> shut up ! <end>
# Translated: shut up !
# --------------------------------------------------
# Arabic: أوقفه
# English: <start> stop it . <end>
# Translated: stop it .
# --------------------------------------------------
# Arabic: خذه
# English: <start> take it . <end>
# Translated: take it .
# --------------------------------------------------
# Arabic: توم فاز.
# English: <start> tom won . <end>
# Translated: tom won .
# --------------------------------------------------
# Arabic: لقد ربح توم.
# English: <start> tom won . <end>
# Translated: tom won .
# --------------------------------------------------
# Arabic: استيقظ!
# English: <start> wake up ! <end>
# Translated: wake up !
# --------------------------------------------------
# Arabic: أهلاً و سهلاً!
# English: <start> welcome . <end>
# Translated: welcome .
# --------------------------------------------------
# Arabic: مرحباً بك!
# English: <start> welcome . <end>
# Translated: welcome .
# --------------------------------------------------
# Arabic: اهلا وسهلا
# English: <start> welcome . <end>
# Translated: welcome .
# --------------------------------------------------
# Arabic: مرحبا!
# English: <start> welcome . <end>
# Translated: welcome .
# --------------------------------------------------
# Arabic: من فاز؟
# English: <start> who won ? <end>
# Translated: who won ?
# --------------------------------------------------
# Arabic: من الذي ربح؟
# English: <start> who won ? <end>
# Translated: who won ?
# --------------------------------------------------
# Arabic: لم لا؟
# English: <start> why not ? <end>
# Translated: why not ?
# --------------------------------------------------
# Arabic: لما لا؟
# English: <start> why not ? <end>
# Translated: why is it ?
# --------------------------------------------------
# Arabic: استمتع بوقتك.
# English: <start> have fun . <end>
# Translated: have fun .
# --------------------------------------------------
# Arabic: أسرع!
# English: <start> hurry up . <end>
# Translated: i saw his hand .
# --------------------------------------------------
# Arabic: لقد نسيت.
# English: <start> i forgot . <end>
# Translated: i forgot .
# --------------------------------------------------
# Arabic: فهمتُهُ.
# English: <start> i got it . <end>
# Translated: i got it .
# --------------------------------------------------
# Arabic: فهمتُها.
# English: <start> i got it . <end>
# Translated: i got it .
# --------------------------------------------------
# Arabic: فَهمتُ ذلك.
# English: <start> i got it . <end>
# Translated: i got it .
# --------------------------------------------------
# Arabic: أستخدمه.
# English: <start> i use it . <end>
# Translated: i use it .
# --------------------------------------------------
# Arabic: سأدفع أنا.
# English: <start> i ll pay . <end>
# Translated: i ll pay .
# --------------------------------------------------
# Arabic: أنا مشغول.
# English: <start> i m busy . <end>
# Translated: i m busy .
# --------------------------------------------------
# Arabic: إنني مشغول.
# English: <start> i m busy . <end>
# Translated: i m busy .
# --------------------------------------------------
# Arabic: أشعر بالبرد.
# English: <start> i m cold . <end>
# Translated: i m cold .
# --------------------------------------------------
# Arabic: أنا حُرّ.
# English: <start> i m free . <end>
# Translated: i m getting ready .
# --------------------------------------------------
# Arabic: أنا هنا
# English: <start> i m here . <end>
# Translated: i m here .
# --------------------------------------------------
# Arabic: لقد عدت إلى البيت
# English: <start> i m home . <end>
# Translated: i m home .
# --------------------------------------------------
# Arabic: أنا فقير.
# English: <start> i m poor . <end>
# Translated: i m poor .
# --------------------------------------------------
# Arabic: أنا ثري.
# English: <start> i m rich . <end>
# Translated: i m rich .
# --------------------------------------------------
# Arabic: هذا مؤلم
# English: <start> it hurts . <end>
# Translated: it hurts .
# --------------------------------------------------
# Arabic: الجو حار
# English: <start> it s hot . <end>
# Translated: it s hot .
# --------------------------------------------------
# Arabic: إنه جديد
# English: <start> it s new . <end>
# Translated: he is new new .
# --------------------------------------------------
# Arabic: هيا بنا!
# English: <start> let s go ! <end>
# Translated: let s go !
# --------------------------------------------------
# Arabic: هيا لنذهب!
# English: <start> let s go ! <end>
# Translated: let s go !
# --------------------------------------------------
# Arabic: لنذهب.
# English: <start> let s go ! <end>
# Translated: we have been deceived .
# --------------------------------------------------
# Arabic: هيا بنا.
# English: <start> let s go . <end>
# Translated: let s go .
# --------------------------------------------------
# Arabic: هيا بنا نذهب.
# English: <start> let s go . <end>
# Translated: let s go .
# --------------------------------------------------
# Arabic: اِنتبه!
# English: <start> look out ! <end>
# Translated: look out !
# --------------------------------------------------
# Arabic: إحذر!
# English: <start> look out ! <end>
# Translated: i ll get rid of your parents .
# --------------------------------------------------
# Arabic: انتبه
# English: <start> look out ! <end>
# Translated: look out !
# --------------------------------------------------
# Arabic: تكلم!
# English: <start> speak up ! <end>
# Translated: speak up !
# --------------------------------------------------
# Arabic: قف!
# English: <start> stand up ! <end>
# Translated: stop !
# --------------------------------------------------
# Arabic: رائع!
# English: <start> terrific ! <end>
# Translated: terrific !
# --------------------------------------------------
# Arabic: ممتاز!
# English: <start> terrific ! <end>
# Translated: terrific !
# --------------------------------------------------
# Arabic: توم مات.
# English: <start> tom died . <end>
# Translated: tom died .
# --------------------------------------------------
# Arabic: توفي توم.
# English: <start> tom died . <end>
# Translated: tom picked up the blanket .
# --------------------------------------------------
# Arabic: لقد غادر توم.
# English: <start> tom left . <end>
# Translated: tom left .
# --------------------------------------------------
# Arabic: لقد كذِبَ توم.
# English: <start> tom lied . <end>
# Translated: tom lied .
# --------------------------------------------------
# Arabic: لقد خَسِرَ توم.
# English: <start> tom lost . <end>
# Translated: tom lost .
# --------------------------------------------------
# Arabic: توم استقال.
# English: <start> tom quit . <end>
# Translated: tom quit .
# --------------------------------------------------
# Arabic: هاك، جرب.
# English: <start> try some . <end>
# Translated: try some .
# --------------------------------------------------
# Arabic: من أنا؟
# English: <start> who am i ? <end>
# Translated: who am i ?
# --------------------------------------------------
# Arabic: من مات؟
# English: <start> who died ? <end>
# Translated: who died ?
# --------------------------------------------------
# Arabic: من توفي؟
# English: <start> who died ? <end>
# Translated: who died ?
# --------------------------------------------------
# Arabic: من بعدك
# English: <start> after you . <end>
# Translated: after you .
# --------------------------------------------------
# Arabic: العصافير تطير.
# English: <start> birds fly . <end>
# Translated: birds fly .
# --------------------------------------------------
# Arabic: تحلق الطيور.
# English: <start> birds fly . <end>
# Translated: birds fly .
# --------------------------------------------------
# Arabic: يُباركك.
# English: <start> bless you . <end>
# Translated: bless you .
# --------------------------------------------------
# Arabic: اِهدأ.
# English: <start> calm down . <end>
# Translated: calm down .
# --------------------------------------------------
# Arabic: هل نستطيع أن نذهب؟
# English: <start> can we go ? <end>
# Translated: are you going to meet , please ?
# --------------------------------------------------
# Arabic: تعال هنا.
# English: <start> come here . <end>
# Translated: come here .
# --------------------------------------------------
# Arabic: تعال إلى هنا.
# English: <start> come here . <end>
# Translated: come here .
# --------------------------------------------------
# Arabic: هل أنا فُزت؟
# English: <start> did i win ? <end>
# Translated: did i win ?
# --------------------------------------------------
# Arabic: افعل ذلك الآن.
# English: <start> do it now . <end>
# Translated: do it now .
# --------------------------------------------------
# Arabic: إياك و الكذب.
# English: <start> don t lie . <end>
# Translated: don t lie .
# --------------------------------------------------
# Arabic: عفواً.
# English: <start> excuse me . <end>
# Translated: did you find a job .
# --------------------------------------------------
# Arabic: رائع!
# English: <start> fantastic ! <end>
# Translated: terrific !
# --------------------------------------------------
# Arabic: انسَ الأمر.
# English: <start> forget it . <end>
# Translated: forget it .
# --------------------------------------------------
# Arabic: انسَ ذلك
# English: <start> forget it . <end>
# Translated: forget it .
# --------------------------------------------------
# Arabic: أُدخُلْ.
# English: <start> go inside . <end>
# Translated: go inside .
# --------------------------------------------------
# Arabic: اذهب إلى النوم
# English: <start> go to bed . <end>
# Translated: go to bed !
# --------------------------------------------------
# Arabic: بالتوفيق.
# English: <start> good luck . <end>
# Translated: good luck .
# --------------------------------------------------
# Arabic: لا تلمسني.
# English: <start> hands off . <end>
# Translated: don t touch me !
# --------------------------------------------------
# Arabic: إنه مريض.
# English: <start> he is ill . <end>
# Translated: he is sick .
# --------------------------------------------------
# Arabic: هو مريض
# English: <start> he is ill . <end>
# Translated: he is ill .
# --------------------------------------------------
# Arabic: كيف توم؟
# English: <start> how s tom ? <end>
# Translated: how s tom ?
# --------------------------------------------------
# Arabic: كيف حال توم؟
# English: <start> how s tom ? <end>
# Translated: how is tom s ?
# --------------------------------------------------
# Arabic: أنا تايلاندي.
# English: <start> i am thai . <end>
# Translated: i am thai .
# --------------------------------------------------
# Arabic: أشعر بالبرد.
# English: <start> i am cold . <end>
# Translated: i m cold .
# --------------------------------------------------
# Arabic: أنا هنا
# English: <start> i am here . <end>
# Translated: i m here .
# --------------------------------------------------
# Arabic: أنا بخير.
# English: <start> i am okay . <end>
# Translated: i m ok .
# --------------------------------------------------
# Arabic: أنا متأكد.
# English: <start> i am sure . <end>
# Translated: i m going to get up .
# --------------------------------------------------
# Arabic: آمل ذلك.
# English: <start> i hope so . <end>
# Translated: i hope that .
# --------------------------------------------------
# Arabic: ضحكت.
# English: <start> i laughed . <end>
# Translated: i laughed .
# --------------------------------------------------
# Arabic: هذا يعجبني.
# English: <start> i like it . <end>
# Translated: this is the reason that i ll be able to this .
# --------------------------------------------------
# Arabic: أنا أحبه.
# English: <start> i love it . <end>
# Translated: i love it .
# --------------------------------------------------
# Arabic: أنا أرى توم
# English: <start> i see tom . <end>
# Translated: i see tom .
# --------------------------------------------------
# Arabic: أنا رجلٌ.
# English: <start> i m a man . <end>
# Translated: i m a man .
# --------------------------------------------------
# Arabic: أنا لوحدي.
# English: <start> i m alone . <end>
# Translated: i m alone .
# --------------------------------------------------
# Arabic: مللت.
# English: <start> i m bored . <end>
# Translated: i m bored .
# --------------------------------------------------
# Arabic: لقد كُسِرت
# English: <start> i m broke . <end>
# Translated: he is broke .
# --------------------------------------------------
# Arabic: أنا سعيد
# English: <start> i m happy . <end>
# Translated: i m happy .
# --------------------------------------------------
# Arabic: انا محظوظ.
# English: <start> i m lucky . <end>
# Translated: i m getting a job .
# --------------------------------------------------
# Arabic: أنا مسكين.
# English: <start> i m needy . <end>
# Translated: i m needy .
# --------------------------------------------------
# Arabic: أنا مستعد.
# English: <start> i m ready . <end>
# Translated: i m ready .
# --------------------------------------------------
# Arabic: أنا مستعدة.
# English: <start> i m ready . <end>
# Translated: i m ready .
# --------------------------------------------------
# Arabic: أنا آسف.
# English: <start> i m sorry . <end>
# Translated: i m sorry .
# --------------------------------------------------
# Arabic: أنا متأسف.
# English: <start> i m sorry . <end>
# Translated: i m sorry .
# --------------------------------------------------
# Arabic: أتأسف.
# English: <start> i m sorry . <end>
# Translated: she took his own life .
# --------------------------------------------------
# Arabic: أنا آسف
# English: <start> i m sorry . <end>
# Translated: i m sorry .
# --------------------------------------------------
# Arabic: أنا متعب.
# English: <start> i m tired . <end>
# Translated: i m tired .
# --------------------------------------------------
# Arabic: هل هذا جديد؟
# English: <start> is it new ? <end>
# Translated: is it new ?
# --------------------------------------------------
# Arabic: إنه جديد
# English: <start> it is new . <end>
# Translated: he is new new .
# --------------------------------------------------
# Arabic: الجو بارد.
# English: <start> it s cold . <end>
# Translated: it is cold .
# --------------------------------------------------
# Arabic: إنها ساعة متأخرة.
# English: <start> it s late . <end>
# Translated: it s late .
# --------------------------------------------------
# Arabic: دَعني أذهب.
# English: <start> let me go . <end>
# Translated: let me go .
# --------------------------------------------------
# Arabic: اسمع
# English: <start> listen up . <end>
# Translated: listen up .
# --------------------------------------------------
# Arabic: انظر خلفك!
# English: <start> look back ! <end>
# Translated: look back !
# --------------------------------------------------
# Arabic: طبعاً!
# English: <start> of course ! <end>
# Translated: of course !
# --------------------------------------------------
# Arabic: بالطبع.
# English: <start> of course . <end>
# Translated: of course .
# --------------------------------------------------
# Arabic: طبعاً.
# English: <start> of course . <end>
# Translated: of course .
# --------------------------------------------------
# Arabic: بالتأكيد.
# English: <start> of course . <end>
# Translated: the absolutely right away .
# --------------------------------------------------
# Arabic: المعذرة؟
# English: <start> pardon me ? <end>
# Translated: i m going to get a doctor .
# --------------------------------------------------
# Arabic: أأنت جاد؟
# English: <start> seriously ? <end>
# Translated: ladies are .
# --------------------------------------------------
# Arabic: هي تمشي
# English: <start> she walks . <end>
# Translated: she is innocent .
# --------------------------------------------------
# Arabic: حافظي على جسم نحيف.
# English: <start> stay thin . <end>
# Translated: he got up at the news on the news on the newspaper .
# --------------------------------------------------
# Arabic: إبقي نحيفة.
# English: <start> stay thin . <end>
# Translated: stay thin .
# --------------------------------------------------
# Arabic: حافظ على نحافتك.
# English: <start> stay thin . <end>
# Translated: stay thin .
# --------------------------------------------------
# Arabic: أوقف ذلك
# English: <start> stop that ! <end>
# Translated: stop that !
# --------------------------------------------------
# Arabic: أوقف ذلك
# English: <start> stop that . <end>
# Translated: stop that !
# --------------------------------------------------
# Arabic: أوقفهم.
# English: <start> stop them . <end>
# Translated: stop them !
# --------------------------------------------------
# Arabic: انتبه!
# English: <start> take care ! <end>
# Translated: take care !
# --------------------------------------------------
# Arabic: مع السلامة.
# English: <start> take care . <end>
# Translated: take care .
# --------------------------------------------------
# Arabic: اعتن بنفسك.
# English: <start> take care . <end>
# Translated: take care .
# --------------------------------------------------
# Arabic: شكراً لك
# English: <start> thank you . <end>
# Translated: thank you .
# --------------------------------------------------
# Arabic: ثم ماذا؟
# English: <start> then what ? <end>
# Translated: then what ?
# --------------------------------------------------
# Arabic: ماذا بعد ذلك؟
# English: <start> then what ? <end>
# Translated: what s that do ?
# --------------------------------------------------
# Arabic: لقد تحرك توم.
# English: <start> tom moved . <end>
# Translated: tom moved .
# --------------------------------------------------
# Arabic: لَوَحَ توم.
# English: <start> tom waved . <end>
# Translated: tom waved .
# --------------------------------------------------
# Arabic: انتبه
# English: <start> watch out ! <end>
# Translated: look out !
# --------------------------------------------------
# Arabic: نشعر بالحرارة
# English: <start> we re hot . <end>
# Translated: we re hot .
# --------------------------------------------------
# Arabic: ما الجديد؟
# English: <start> what s up ? <end>
# Translated: what s new ?
# --------------------------------------------------
# Arabic: من يهمّه؟
# English: <start> who cares ? <end>
# Translated: who cares ?
# --------------------------------------------------
# Arabic: مَن؟
# English: <start> who is it ? <end>
# Translated: who is it ?
# --------------------------------------------------
# Arabic: من يدري؟
# English: <start> who knows ? <end>
# Translated: who knows ?
# --------------------------------------------------
# Arabic: من يعلم؟
# English: <start> who knows ? <end>
# Translated: who s my suitcase .
# --------------------------------------------------
# Arabic: مذهل.
# English: <start> wonderful ! <end>
# Translated: wonderful !
# --------------------------------------------------
# Arabic: يا أحمق!
# English: <start> you idiot ! <end>
# Translated: you idiot !
# --------------------------------------------------
# Arabic: يا غبي!
# English: <start> you idiot ! <end>
# Translated: we re going to be able to !
# --------------------------------------------------
# Arabic: لقد حاولت وسعك.
# English: <start> you tried . <end>
# Translated: you tried .
# --------------------------------------------------
# Arabic: ليركب الجميع.
# English: <start> all aboard ! <end>
# Translated: all aboard !
# --------------------------------------------------
# Arabic: ليركب الكل.
# English: <start> all aboard ! <end>
# Translated: all aboard !
# --------------------------------------------------
# Arabic: هل هذا واضح؟
# English: <start> am i clear ? <end>
# Translated: is that clear ?
# --------------------------------------------------
# Arabic: هل أنا مخطئ؟
# English: <start> am i wrong ? <end>
# Translated: am i wrong ?
# --------------------------------------------------
# Arabic: كن حذرا.
# English: <start> be careful . <end>
# Translated: be careful .
# --------------------------------------------------
# Arabic: كُن جدياً.
# English: <start> be serious . <end>
# Translated: be serious .
# --------------------------------------------------
# Arabic: الطيور تغرد.
# English: <start> birds sing . <end>
# Translated: birds sing .
# --------------------------------------------------
# Arabic: الى القاع .
# English: <start> bottoms up ! <end>
# Translated: bottoms up !
# --------------------------------------------------
# Arabic: برشفة واحدة .
# English: <start> bottoms up ! <end>
# Translated: bottoms up !
# --------------------------------------------------
# Arabic: أحضر الطعام.
# English: <start> bring food . <end>
# Translated: bring food .
# --------------------------------------------------
# Arabic: أحضِر المُساعدة.
# English: <start> bring help . <end>
# Translated: bring help .
# --------------------------------------------------
# Arabic: أحضر الخمر.
# English: <start> bring wine . <end>
# Translated: bring wine .
# --------------------------------------------------
# Arabic: أحضر النبيذ.
# English: <start> bring wine . <end>
# Translated: bring wine .
# --------------------------------------------------
# Arabic: هل أستطيع أن أبقى؟
# English: <start> can i stay ? <end>
# Translated: can i stay ?
# --------------------------------------------------
# Arabic: احمل هذا.
# English: <start> carry this . <end>
# Translated: carry this .
# --------------------------------------------------
# Arabic: إفحص ذلك.
# English: <start> check that . <end>
# Translated: check that .
# --------------------------------------------------
# Arabic: إفحص هذا.
# English: <start> check this . <end>
# Translated: check this .
# --------------------------------------------------
# Arabic: تعالَ مُجدداً.
# English: <start> come again . <end>
# Translated: come again .
# --------------------------------------------------
# Arabic: تعالَ وحدك.
# English: <start> come alone . <end>
# Translated: come alone .
# --------------------------------------------------
# Arabic: تعالَ بمفردك.
# English: <start> come alone . <end>
# Translated: come alone .
# --------------------------------------------------
# Arabic: تعال معنا.
# English: <start> come along . <end>
# Translated: come with us .
# --------------------------------------------------
# Arabic: هيا ادخل
# English: <start> come on in ! <end>
# Translated: come on in !
# --------------------------------------------------
# Arabic: هيا ادخل
# English: <start> come on in . <end>
# Translated: come on in !
# --------------------------------------------------
# Arabic: تعال بسرعة.
# English: <start> come quick ! <end>
# Translated: come great has fast .
# --------------------------------------------------
# Arabic: تعال إلي
# English: <start> come to me . <end>
# Translated: come to me .
# --------------------------------------------------
# Arabic: قطعاً
# English: <start> definitely ! <end>
# Translated: definitely !
# --------------------------------------------------
# Arabic: لا تتحرك.
# English: <start> don t move . <end>
# Translated: don t move .
# --------------------------------------------------
# Arabic: املئها.
# English: <start> fill it up . <end>
# Translated: the climate of france are selling him .
# --------------------------------------------------
# Arabic: اتبعه.
# English: <start> follow him . <end>
# Translated: i ll get out .
# --------------------------------------------------
# Arabic: اذهب إلى العمل
# English: <start> go to work . <end>
# Translated: go to work .
# --------------------------------------------------
# Arabic: إنه لطيف.
# English: <start> he is nice . <end>
# Translated: he is nice .
# --------------------------------------------------
# Arabic: إنه مريض.
# English: <start> he is sick . <end>
# Translated: he is sick .
# --------------------------------------------------
# Arabic: هو سعيد
# English: <start> he s happy . <end>
# Translated: he is happy .
# --------------------------------------------------
# Arabic: هو ذكي.
# English: <start> he s smart . <end>
# Translated: he s smart .
# --------------------------------------------------
# Arabic: إنه ذكي.
# English: <start> he s smart . <end>
# Translated: he s smart .
# --------------------------------------------------
# Arabic: ها هو هنا
# English: <start> here he is ! <end>
# Translated: here s what he is ?
# --------------------------------------------------
# Arabic: ها هي.
# English: <start> here it is . <end>
# Translated: here he is a help her .
# --------------------------------------------------
# Arabic: أنا ولد.
# English: <start> i am a boy . <end>
# Translated: i m a boy .
# --------------------------------------------------
# Arabic: أنا أشعر بالملل.
# English: <start> i am bored . <end>
# Translated: i am bored .
# --------------------------------------------------
# Arabic: أنا ذاهب.
# English: <start> i am going . <end>
# Translated: i m going to go .
# --------------------------------------------------
# Arabic: أنا سعيد
# English: <start> i am happy . <end>
# Translated: i m happy .
# --------------------------------------------------
# Arabic: أنا آسف
# English: <start> i am sorry . <end>
# Translated: i m sorry .
# --------------------------------------------------
# Arabic: يمكنني القفز.
# English: <start> i can jump . <end>
# Translated: i can jump .
# --------------------------------------------------
# Arabic: أستطيع القفز.
# English: <start> i can jump . <end>
# Translated: i can jump .
# --------------------------------------------------
# Arabic: يمكنني أن أقفز.
# English: <start> i can jump . <end>
# Translated: i can jump .
# --------------------------------------------------
# Arabic: يمكنني السباحة.
# English: <start> i can swim . <end>
# Translated: i can swim .
# --------------------------------------------------
# Arabic: بإمكاني أن أسبح.
# English: <start> i can swim . <end>
# Translated: i can swim .
# --------------------------------------------------
# Arabic: سآكل هنا.
# English: <start> i eat here . <end>
# Translated: i ll eat it here .
# --------------------------------------------------
# Arabic: أنا أحسدها.
# English: <start> i envy her . <end>
# Translated: i envy her .
# --------------------------------------------------
# Arabic: شعرت بالحزن.
# English: <start> i felt sad . <end>
# Translated: i felt sad .
# --------------------------------------------------
# Arabic: أنا أسمعك
# English: <start> i hear you . <end>
# Translated: i hear you .
# --------------------------------------------------
# Arabic: أعرِفها.
# English: <start> i know her . <end>
# Translated: i know her .
# --------------------------------------------------
# Arabic: أنا أعرفها
# English: <start> i know her . <end>
# Translated: i know her .
# --------------------------------------------------
# Arabic: أعرفه.
# English: <start> i know him . <end>
# Translated: i know him .
# --------------------------------------------------
# Arabic: أنا أعرفه
# English: <start> i know him . <end>
# Translated: i know him .
# --------------------------------------------------
# Arabic: أحبك.
# English: <start> i like you . <end>
# Translated: i do you love you .
# --------------------------------------------------
# Arabic: تعجبني.
# English: <start> i like you . <end>
# Translated: i like her .
# --------------------------------------------------
# Arabic: أحبها.
# English: <start> i love her . <end>
# Translated: what love him ?
# --------------------------------------------------
# Arabic: أنا أحبها
# English: <start> i love her . <end>
# Translated: i love her .
# --------------------------------------------------
# Arabic: أنا أحبك.
# English: <start> i love you . <end>
# Translated: i love you .
# --------------------------------------------------
# Arabic: أحبك.
# English: <start> i love you . <end>
# Translated: i do you love you .
# --------------------------------------------------
# Arabic: انا احبك
# English: <start> i love you . <end>
# Translated: i love you .
# --------------------------------------------------
# Arabic: أنا أحبك
# English: <start> i love you . <end>
# Translated: i love you .
# --------------------------------------------------
# Arabic: قصدت ذلك.
# English: <start> i meant it . <end>
# Translated: i meant it .
# --------------------------------------------------
# Arabic: أشتاق إليه.
# English: <start> i miss him . <end>
# Translated: i miss him .
# --------------------------------------------------
# Arabic: اشتقت إليك.
# English: <start> i miss you . <end>
# Translated: i miss you .
# --------------------------------------------------
# Arabic: افتقدتك.
# English: <start> i miss you . <end>
# Translated: i miss you .
# --------------------------------------------------
# Arabic: أحتاج إليك.
# English: <start> i need you . <end>
# Translated: i need you .
# --------------------------------------------------
# Arabic: أحتاجك.
# English: <start> i need you . <end>
# Translated: i need you .
# --------------------------------------------------
# Arabic: استقلت.
# English: <start> i resigned . <end>
# Translated: i resigned .
# --------------------------------------------------
# Arabic: لقد رأيت ذلك
# English: <start> i saw that . <end>
# Translated: i saw that .
# --------------------------------------------------
# Arabic: أعتقد ذلك.
# English: <start> i think so . <end>
# Translated: i think so .
# --------------------------------------------------
# Arabic: أظن ذلك.
# English: <start> i think so . <end>
# Translated: i think so .
# --------------------------------------------------
# Arabic: أريدك.
# English: <start> i want you . <end>
# Translated: i want you want you .
# --------------------------------------------------
# Arabic: أنا بخير الآن.
# English: <start> i m ok now . <end>
# Translated: i m doing now .
# --------------------------------------------------
# Arabic: أنا بطل.
# English: <start> i m a hero . <end>
# Translated: i m a hero .
# --------------------------------------------------
# Arabic: سآتي.
# English: <start> i m coming . <end>
# Translated: him re right .
# --------------------------------------------------
# Arabic: أنا آتٍ
# English: <start> i m coming . <end>
# Translated: i m coming .
# --------------------------------------------------
# Arabic: أشعر بالجوع.
# English: <start> i m hungry ! <end>
# Translated: i am hungry .
# --------------------------------------------------
# Arabic: لست على ما يرام.
# English: <start> i m not ok . <end>
# Translated: i m not ok .
# --------------------------------------------------
# Arabic: أنا نعسان!
# English: <start> i m sleepy ! <end>
# Translated: i m sleepy !
# --------------------------------------------------
# Arabic: أنا بدين جداً.
# English: <start> i m so fat . <end>
# Translated: i m so fat .
# --------------------------------------------------
# Arabic: أنا شديد البدانة.
# English: <start> i m so fat . <end>
# Translated: i m so fat .
# --------------------------------------------------
# Arabic: أنا سمين جدا.
# English: <start> i m so fat . <end>
# Translated: i m so fat .
# --------------------------------------------------
# Arabic: لست متأكّدا.
# English: <start> i m unsure . <end>
# Translated: i m unsure .
# --------------------------------------------------
# Arabic: هل هذا هو الحب؟
# English: <start> is it love ? <end>
# Translated: is it love ?
# --------------------------------------------------
# Arabic: الجو بارد.
# English: <start> it is cold . <end>
# Translated: it is cold .
# --------------------------------------------------
# Arabic: الحساب عليّ.
# English: <start> it s on me . <end>
# Translated: it s on me .
# --------------------------------------------------
# Arabic: دَع توم يذهب.
# English: <start> let tom go . <end>
# Translated: let tom go .
# --------------------------------------------------
# Arabic: دعه يذهب!
# English: <start> let him go ! <end>
# Translated: let him go !
# --------------------------------------------------
# Arabic: دَعَهُ يذهب.
# English: <start> let him go . <end>
# Translated: let him go .
# --------------------------------------------------
# Arabic: دعني أخرُج!
# English: <start> let me out ! <end>
# Translated: let me think of your phone .
# --------------------------------------------------
# Arabic: انظر مرة أخرى
# English: <start> look again . <end>
# Translated: look again .
# --------------------------------------------------
# Arabic: انظر إليّ.
# English: <start> look at me . <end>
# Translated: look at me .
# --------------------------------------------------
# Arabic: انظر إلي
# English: <start> look at me . <end>
# Translated: look at me .
# --------------------------------------------------
# Arabic: لا عليك!
# English: <start> never mind ! <end>
# Translated: don t write your address ?
# --------------------------------------------------
# Arabic: لا مشكلة!
# English: <start> no problem ! <end>
# Translated: no problem !
# --------------------------------------------------
# Arabic: مرة أخرى.
# English: <start> once again . <end>
# Translated: thank you for any more .
# --------------------------------------------------
# Arabic: مجدداً.
# English: <start> once again . <end>
# Translated: once again .
# --------------------------------------------------
# Arabic: كلمني!
# English: <start> talk to me ! <end>
# Translated: talk to me !
# --------------------------------------------------
# Arabic: ذاك مبلل.
# English: <start> that s wet . <end>
# Translated: that s wet .
# --------------------------------------------------
# Arabic: توم كبير
# English: <start> tom is big . <end>
# Translated: tom is big .
# --------------------------------------------------
# Arabic: توم إبتسم.
# English: <start> tom smiled . <end>
# Translated: tom smiled .
# --------------------------------------------------
# Arabic: توم تثاءب.
# English: <start> tom yawned . <end>
# Translated: tom tells you .
# --------------------------------------------------
# Arabic: توم هنا
# English: <start> tom s here . <end>
# Translated: tom is here .
# --------------------------------------------------
# Arabic: نحن رجال.
# English: <start> we are men . <end>
# Translated: we are men .
# --------------------------------------------------
# Arabic: إننا رجال.
# English: <start> we are men . <end>
# Translated: we are men .
# --------------------------------------------------
# Arabic: ما الأمر؟
# English: <start> what gives ? <end>
# Translated: what s the matter ?
# --------------------------------------------------
# Arabic: ما الجديد؟
# English: <start> what s new ? <end>
# Translated: what s new ?
# --------------------------------------------------
# Arabic: الخشب يحترق.
# English: <start> wood burns . <end>
# Translated: wood burns .
# --------------------------------------------------
# Arabic: يمكنك الذهاب.
# English: <start> you may go . <end>
# Translated: you can find a need to leave .
# --------------------------------------------------
# Arabic: هل أنت غاضب؟
# English: <start> are you mad ? <end>
# Translated: are you mad ?
# --------------------------------------------------
# Arabic: هل أنتِ حزينة؟
# English: <start> are you sad ? <end>
# Translated: are you sad ?
# --------------------------------------------------
# Arabic: كُن مُبدِعاً.
# English: <start> be creative . <end>
# Translated: be merciful .
# --------------------------------------------------
# Arabic: كُن خلاقاً.
# English: <start> be creative . <end>
# Translated: be creative .
# --------------------------------------------------
# Arabic: كُن حَذِراً.
# English: <start> be discreet . <end>
# Translated: be discreet .
# --------------------------------------------------
# Arabic: كُن ودوداً.
# English: <start> be friendly . <end>
# Translated: be friendly .
# --------------------------------------------------
# Arabic: كُن رحيماً.
# English: <start> be merciful . <end>
# Translated: be merciful .
# --------------------------------------------------
# Arabic: كُن مُستعداً.
# English: <start> be prepared . <end>
# Translated: be prepared .
# --------------------------------------------------
# Arabic: كن مستعداً
# English: <start> be prepared . <end>
# Translated: be prepared .
# --------------------------------------------------
# Arabic: كونوا مستعدين
# English: <start> be prepared . <end>
# Translated: i have to be ready .
# --------------------------------------------------
# Arabic: كُن عديم الرحمة.
# English: <start> be ruthless . <end>
# Translated: be ruthless .
# --------------------------------------------------
# Arabic: كُن معقول.
# English: <start> be sensible . <end>
# Translated: be sensible .
# --------------------------------------------------
# Arabic: كُن محدداً.
# English: <start> be specific . <end>
# Translated: be specific .
# --------------------------------------------------
# Arabic: كُن مُتسامحاً.
# English: <start> be tolerant . <end>
# Translated: be merciful .
# --------------------------------------------------
# Arabic: توخى الحذر.
# English: <start> be vigilant . <end>
# Translated: be vigilant .
# --------------------------------------------------
# Arabic: راجع مُجدداً.
# English: <start> check again . <end>
# Translated: again tomorrow , i ll come again .
# --------------------------------------------------
# Arabic: إفحص مُجدداً.
# English: <start> check again . <end>
# Translated: check again .
# --------------------------------------------------
# Arabic: تحقق مجدداً.
# English: <start> check again . <end>
# Translated: check again .
# --------------------------------------------------
# Arabic: إقتَرِب.
# English: <start> come closer . <end>
# Translated: come closer .
# --------------------------------------------------
# Arabic: تعالَ بالداخل.
# English: <start> come inside . <end>
# Translated: come inside .
# --------------------------------------------------
# Arabic: إتصل بتوم.
# English: <start> contact tom . <end>
# Translated: contact tom .
# --------------------------------------------------
# Arabic: هل مات توم؟
# English: <start> did tom die ? <end>
# Translated: did tom die ?
# --------------------------------------------------
# Arabic: لا تُجادِل.
# English: <start> don t argue . <end>
# Translated: don t you re eating .
# --------------------------------------------------
# Arabic: لا تَغِش.
# English: <start> don t cheat . <end>
# Translated: don t cheat .
# --------------------------------------------------
# Arabic: لا تفعل ذلك!
# English: <start> don t do it ! <end>
# Translated: don t do it !
# --------------------------------------------------
# Arabic: لا تقلق.
# English: <start> don t worry . <end>
# Translated: don t worry . don t worry .
# --------------------------------------------------
# Arabic: لا عليك.
# English: <start> don t worry . <end>
# Translated: don t you do your job .
# --------------------------------------------------
# Arabic: إذهب وابحث عن طوم.
# English: <start> go find tom . <end>
# Translated: go find tom .
# --------------------------------------------------
# Arabic: استرح.
# English: <start> have a seat . <end>
# Translated: stand at ease !
# --------------------------------------------------
# Arabic: بإمكانه المجيء
# English: <start> he can come . <end>
# Translated: he can come .
# --------------------------------------------------
# Arabic: إنه وحيد.
# English: <start> he is alone . <end>
# Translated: he is alone .
# --------------------------------------------------
# Arabic: إنه وحده.
# English: <start> he is alone . <end>
# Translated: he is alone .
# --------------------------------------------------
# Arabic: هو سعيد
# English: <start> he is happy . <end>
# Translated: he is happy .
# --------------------------------------------------
# Arabic: إنه قوي.
# English: <start> he s strong . <end>
# Translated: he s strong .
# --------------------------------------------------
# Arabic: ها نحن ذا
# English: <start> here we are ! <end>
# Translated: there are a time , we are !
# --------------------------------------------------
# Arabic: ها قد وصلنا.
# English: <start> here we are . <end>
# Translated: there are you .
# --------------------------------------------------
# Arabic: ها نحن هنا
# English: <start> here we are . <end>
# Translated: here we are .
# --------------------------------------------------
# Arabic: كيف حالك؟
# English: <start> how are you ? <end>
# Translated: how are you ?
# --------------------------------------------------
# Arabic: كيفَ حالك؟
# English: <start> how are you ? <end>
# Translated: how are you ?
# --------------------------------------------------
# Arabic: كيفَ حالِك؟
# English: <start> how are you ? <end>
# Translated: how are you ?
# --------------------------------------------------
# Arabic: ذهبت أيضاً.
# English: <start> i also went . <end>
# Translated: i also went .
# --------------------------------------------------
# Arabic: أنا خائف.
# English: <start> i am afraid . <end>
# Translated: i am afraid .
# --------------------------------------------------
# Arabic: أنا آتٍ.
# English: <start> i am coming . <end>
# Translated: i am coming .
# --------------------------------------------------
# Arabic: أنا آتٍ
# English: <start> i am coming . <end>
# Translated: i m coming .
# --------------------------------------------------
# Arabic: أشعر بالجوع.
# English: <start> i am hungry . <end>
# Translated: i am hungry .
# --------------------------------------------------
# Arabic: حفرت حفرة.
# English: <start> i dug a pit . <end>
# Translated: i found the cave .
# --------------------------------------------------
# Arabic: أشعر بالبرد.
# English: <start> i feel cold . <end>
# Translated: i m cold .
# --------------------------------------------------
# Arabic: أحب موسيقى الجاز.
# English: <start> i like jazz . <end>
# Translated: i like jazz .
# --------------------------------------------------
# Arabic: أحب الرز
# English: <start> i like rice . <end>
# Translated: which do you like to get up ?
# --------------------------------------------------
# Arabic: أعيش هنا.
# English: <start> i live here . <end>
# Translated: i live here .
# --------------------------------------------------
# Arabic: أنا أسكن هنا
# English: <start> i live here . <end>
# Translated: i live here .
# --------------------------------------------------
# Arabic: أعشق موسيقى الروك.
# English: <start> i love rock . <end>
# Translated: they ll get jazz .
# --------------------------------------------------
# Arabic: عليّ الاختباء.
# English: <start> i must hide . <end>
# Translated: i must hide .
# --------------------------------------------------
# Arabic: أحتاج وقتا.
# English: <start> i need time . <end>
# Translated: i need time .
# --------------------------------------------------
# Arabic: قلت ذلك.
# English: <start> i said that . <end>
# Translated: you told me that .
# --------------------------------------------------
# Arabic: أثق بك.
# English: <start> i trust you . <end>
# Translated: i trust you .
# --------------------------------------------------
# Arabic: أنا أثق فيك.
# English: <start> i trust you . <end>
# Translated: i trust you .
# --------------------------------------------------
# Arabic: أنا أثق بك.
# English: <start> i trust you . <end>
# Translated: i trust you .
# --------------------------------------------------
# Arabic: أريد المزيد
# English: <start> i want more . <end>
# Translated: i want more .
# --------------------------------------------------
# Arabic: كنت مخطئاً.
# English: <start> i was wrong . <end>
# Translated: i was wrong .
# --------------------------------------------------
# Arabic: سأحضر.
# English: <start> i ll attend . <end>
# Translated: i ll attend .
# --------------------------------------------------
# Arabic: سأقرر.
# English: <start> i ll decide . <end>
# Translated: it was years since .
# --------------------------------------------------
# Arabic: أنا خباز
# English: <start> i m a baker . <end>
# Translated: i m a baker .
# --------------------------------------------------
# Arabic: أنا امرأةٌ.
# English: <start> i m a woman . <end>
# Translated: i m a woman .
# --------------------------------------------------
# Arabic: إني في المنزل.
# English: <start> i m at home . <end>
# Translated: i m at home .
# --------------------------------------------------
# Arabic: أنا في البيت.
# English: <start> i m at home . <end>
# Translated: i m at home .
# --------------------------------------------------
# Arabic: أنا في البيت
# ...
# --------------------------------------------------
# Arabic: لقد رأيت ذلك من قبل.
# English: <start> i ve seen that . <end>
# Translated: i ve seen that .
# --------------------------------------------------
# Arabic: لو أنّني كنت أعرف!
# English: <start> if only i knew ! <end>
# Translated: if i knew !
# --------------------------------------------------
# Arabic: أهو أمريكي؟
# English: <start> is he american ? <end>
# Translated: is he american ?
# --------------------------------------------------
# Arabic: هل هو ياباني؟
# English: <start> is he japanese ? <end>
# Translated: is he japanese ?
# --------------------------------------------------
# Arabic: هل هذه فرنسية؟
# English: <start> is this french ? <end>
# Translated: is this french ?
# --------------------------------------------------
# Arabic: أليست سوداء؟
# English: <start> isn t it black ? <end>
# Translated: is it not black ?
# --------------------------------------------------
# Arabic: أليس أسوداً؟
# English: <start> isn t it black ? <end>
# Translated: isn t it black ?
# --------------------------------------------------
# Arabic: هل اليوم هو السبت؟
# English: <start> it is saturday . <end>
# Translated: it is saturday .
# --------------------------------------------------
# Arabic: الوقت مبكر جدا.
# English: <start> it is so early . <end>
# Translated: it is so early .
# --------------------------------------------------
# Arabic: كان ذلك فأراً.
# English: <start> it was a mouse . <end>
# Translated: it was getting used to your homework .
# --------------------------------------------------
# Arabic: إنها جديدة.
# English: <start> it s brand new . <end>
# Translated: it s my new .
# --------------------------------------------------
# Arabic: إنك في خطر!
# English: <start> it s dangerous ! <end>
# Translated: it s dangerous !
# --------------------------------------------------
# Arabic: الجو حار اليوم.
# English: <start> it s hot today . <end>
# Translated: it s hot today .
# --------------------------------------------------
# Arabic: اليوم حار
# English: <start> it s hot today . <end>
# Translated: today is too hot .
# --------------------------------------------------
# Arabic: إنها جاهزة الأن.
# English: <start> it s ready now . <end>
# Translated: it s ready now .
# --------------------------------------------------
# Arabic: إنها الملكة.
# English: <start> it s the queen . <end>
# Translated: it s the queen .
# --------------------------------------------------
# Arabic: إنها صغيرة جداً.
# English: <start> it s too small . <end>
# Translated: it s too small .
# --------------------------------------------------
# Arabic: إنها صغيرة جداً
# English: <start> it s too small . <end>
# Translated: it s too small .
# --------------------------------------------------
# Arabic: الأمر يعود إليك.
# English: <start> it s up to you . <end>
# Translated: it s up to you to decide .
# --------------------------------------------------
# Arabic: كما تريد.
# English: <start> it s up to you . <end>
# Translated: it s up to you to see the park .
# --------------------------------------------------
# Arabic: إن الجو قارس.
# English: <start> it s very cold . <end>
# Translated: it s very cold .
# --------------------------------------------------
# Arabic: الجو بارد جداً.
# English: <start> it s very cold . <end>
# Translated: it s very cold .
# --------------------------------------------------
# Arabic: هذا جيد جدا
# English: <start> it s very good . <end>
# Translated: it s very good .
# --------------------------------------------------
# Arabic: حسنًا عُمِلَ.
# English: <start> it s well done . <end>
# Translated: you would like to talk to him ?
# --------------------------------------------------
# Arabic: إنه كتابك.
# English: <start> it s your book . <end>
# Translated: it s your book .
# --------------------------------------------------
# Arabic: إنه دورك.
# English: <start> it s your turn . <end>
# Translated: it s your turn .
# --------------------------------------------------
# Arabic: اتبعني فحسب.
# English: <start> just follow me . <end>
# Translated: just follow me .
# --------------------------------------------------
# Arabic: دع الأمر لي.
# English: <start> leave it to me . <end>
# Translated: leave it to me .
# --------------------------------------------------
# Arabic: اتركني و شأني!
# English: <start> leave me alone ! <end>
# Translated: leave me alone !
# --------------------------------------------------
# Arabic: دعني و شأني!
# English: <start> leave me alone ! <end>
# Translated: leave me alone !
# --------------------------------------------------
# Arabic: لنعُد إلى البيت.
# English: <start> let us go home . <end>
# Translated: i ll go home .
# --------------------------------------------------
# Arabic: هيا لنرجع إلى المنزل.
# English: <start> let us go home . <end>
# Translated: let us go home .
# --------------------------------------------------
# Arabic: دعونا لا نتحدث.
# English: <start> let s not talk . <end>
# Translated: let s not talk .
# --------------------------------------------------
# Arabic: دعينا لا نتحدث.
# English: <start> let s not talk . <end>
# Translated: let s not talk .
# --------------------------------------------------
# Arabic: دعنا لا نتحدث.
# English: <start> let s not talk . <end>
# Translated: let s not talk .
# --------------------------------------------------
# Arabic: لنشاهد التلفاز.
# English: <start> let s watch tv . <end>
# Translated: let s watch tv .
# --------------------------------------------------
# Arabic: لنشاهد الرائي.
# English: <start> let s watch tv . <end>
# Translated: let s watch tv .
# --------------------------------------------------
# Arabic: لنشاهد التلفزيون.
# English: <start> let s watch tv . <end>
# Translated: let s watch tv .
# --------------------------------------------------
# Arabic: اعتني بتوم
# English: <start> look after tom . <end>
# Translated: look after tom .
# --------------------------------------------------
# Arabic: من فضلك، ارفع صوتك.
# English: <start> louder , please . <end>
# Translated: louder , please .
# --------------------------------------------------
# Arabic: لين تركض بسرعة.
# English: <start> lynn runs fast . <end>
# Translated: lynn runs fast .
# --------------------------------------------------
# Arabic: هل تحتاج لمساعدة؟
# English: <start> may i help you ? <end>
# Translated: may i help you ?
# --------------------------------------------------
# Arabic: هل لي أن أساعدك؟
# English: <start> may i help you ? <end>
# Translated: can i help you ?
# --------------------------------------------------
# Arabic: أيمكنني مساعدتك؟
# English: <start> may i help you ? <end>
# Translated: can i help you ?
# --------------------------------------------------
# Arabic: هل يمكنني أن اساعدك؟
# English: <start> may i help you ? <end>
# Translated: may i help you ?
# --------------------------------------------------
# Arabic: أيمكنني الجلوس؟
# English: <start> may i sit down ? <end>
# Translated: may i sit down ?
# --------------------------------------------------
# Arabic: أيمكنني الجلوس هنا؟
# English: <start> may i sit here ? <end>
# Translated: can i come in the table ?
# --------------------------------------------------
# Arabic: هل يمكنني استخدام هذا؟
# English: <start> may i use this ? <end>
# Translated: may i use this ?
# --------------------------------------------------
# Arabic: مفاصلي تؤلمني.
# English: <start> my joints ache . <end>
# Translated: my joints ache .
# --------------------------------------------------
# Arabic: سني يؤلمني.
# English: <start> my tooth hurts . <end>
# Translated: my tooth hurts .
# --------------------------------------------------
# Arabic: الآن تذكرت.
# English: <start> now i remember . <end>
# Translated: now i remember the bill .
# --------------------------------------------------
# Arabic: تذكرت الآن.
# English: <start> now i remember . <end>
# Translated: now i remember .
# --------------------------------------------------
# Arabic: الله وحده يعلم.
# English: <start> only god knows . <end>
# Translated: only god knows .
# --------------------------------------------------
# Arabic: الناس يحبونني.
# English: <start> people like me . <end>
# Translated: people like me .
# --------------------------------------------------
# Arabic: تفضل بالدخول.
# English: <start> please come in . <end>
# Translated: please come in .
# --------------------------------------------------
# Arabic: تفضّل بالدّخول.
# English: <start> please come in . <end>
# Translated: please come in .
# --------------------------------------------------
# Arabic: من فضلك ساعدني.
# English: <start> please help me . <end>
# Translated: could you help me ?
# --------------------------------------------------
# Arabic: انتظر قليلاً.
# English: <start> please hold on . <end>
# Translated: please hold on .
# --------------------------------------------------
# Arabic: ارتفعت الأسعار.
# English: <start> prices went up . <end>
# Translated: prices went up .
# --------------------------------------------------
# Arabic: زرعت ورداً.
# English: <start> she grew roses . <end>
# Translated: she grew roses .
# --------------------------------------------------
# Arabic: ربما ستأتي.
# English: <start> she might come . <end>
# Translated: she may come .
# --------------------------------------------------
# Arabic: من الممكن أنها ستأتي.
# English: <start> she might come . <end>
# Translated: she may come from .
# --------------------------------------------------
# Arabic: هي ليست هنا
# English: <start> she s not here . <end>
# Translated: she s not here .
# --------------------------------------------------
# Arabic: خذ وقتك.
# English: <start> take your time . <end>
# Translated: take your time .
# --------------------------------------------------
# Arabic: شكرا جزيلا.
# English: <start> thanks a bunch . <end>
# Translated: thanks a bunch .
# --------------------------------------------------
# Arabic: ذاك فندقٌ.
# English: <start> that s a hotel . <end>
# Translated: that s a hotel .
# --------------------------------------------------
# Arabic: ذلك فندقٌ.
# English: <start> that s a hotel . <end>
# Translated: that s a hotel .
# --------------------------------------------------
# Arabic: هذا كتابي.
# English: <start> that s my book . <end>
# Translated: that s my book .
# --------------------------------------------------
# Arabic: غردت العصافير.
# English: <start> the birds sang . <end>
# Translated: my uncle is delicious .
# --------------------------------------------------
# Arabic: كلهم سكارى.
# English: <start> they all drank . <end>
# Translated: they all drank .
# --------------------------------------------------
# Arabic: إنهم سعداء
# English: <start> they are happy . <end>
# Translated: they are happy .
# --------------------------------------------------
# Arabic: هم سعداء
# English: <start> they are happy . <end>
# Translated: they re happy .
# --------------------------------------------------
# Arabic: كانوا يكرهون توم.
# English: <start> they hated tom . <end>
# Translated: they hated tom .
# --------------------------------------------------
# Arabic: هُم تركوني أذهب.
# English: <start> they let me go . <end>
# Translated: they let me go .
# --------------------------------------------------
# Arabic: فكر في ذلك.
# English: <start> think about it . <end>
# Translated: think about it .
# --------------------------------------------------
# Arabic: فكر بذلك
# English: <start> think about it . <end>
# Translated: think about it .
# --------------------------------------------------
# Arabic: هذا كتاب.
# English: <start> this is a book . <end>
# Translated: this is a book .
# --------------------------------------------------
# Arabic: هذه نكتة.
# English: <start> this is a joke . <end>
# Translated: this is a pun .
# --------------------------------------------------
# Arabic: هذه سيارتي.
# English: <start> this is my car . <end>
# Translated: this is my car .
# --------------------------------------------------
# Arabic: حان وقت الإستيقاظ.
# English: <start> time to get up . <end>
# Translated: time to get up .
# --------------------------------------------------
# Arabic: توم ينتظر.
# English: <start> tom is waiting . <end>
# Translated: tom is watching .
# --------------------------------------------------
# Arabic: توم ليس هنا
# English: <start> tom isn t here . <end>
# Translated: tom isn t here .
# --------------------------------------------------
# Arabic: توم ليس في البيت
# English: <start> tom isn t home . <end>
# Translated: tom isn t home .
# --------------------------------------------------
# Arabic: توم يعلم ذلك
# English: <start> tom knows that . <end>
# Translated: tom knows that .
# --------------------------------------------------
# Arabic: يبدو توم شاحب الوجه.
# English: <start> tom looks pale . <end>
# Translated: tom looks pale .
# --------------------------------------------------
# Arabic: توم ليس في البيت
# English: <start> tom s not home . <end>
# Translated: tom isn t home .
# --------------------------------------------------
# Arabic: توم هو الأفضل.
# English: <start> tom s the best . <end>
# Translated: tom s the best .
# --------------------------------------------------
# Arabic: توم يشاهد
# English: <start> tom s watching . <end>
# Translated: tom s watching .
# --------------------------------------------------
# Arabic: اِغسل رجليك.
# English: <start> wash your feet . <end>
# Translated: hey , your hands yet .
# --------------------------------------------------
# Arabic: راقب الجزء الخلفي .
# English: <start> watch the rear . <end>
# Translated: watch the rear .
# --------------------------------------------------
# Arabic: نحن في المنزل
# English: <start> we are at home . <end>
# Translated: we re at home .
# --------------------------------------------------
# Arabic: جعلناه يذهب.
# English: <start> we made him go . <end>
# Translated: we made him go .
# --------------------------------------------------
# Arabic: سنجد واحدا.
# English: <start> we ll find one . <end>
# Translated: we ll find one .
# --------------------------------------------------
# Arabic: سنقتلك.
# English: <start> we ll kill you . <end>
# Translated: we ll kill you .
# --------------------------------------------------
# Arabic: نحن مطيعون.
# English: <start> we re obedient . <end>
# Translated: we re obedient .
# --------------------------------------------------
# Arabic: نحن بمأمن الآن.
# English: <start> we re safe now . <end>
# Translated: we re safe now .
# --------------------------------------------------
# Arabic: نحن في أمان الآن.
# English: <start> we re safe now . <end>
# Translated: we re safe now .
# --------------------------------------------------
# Arabic: نحن طلاب
# English: <start> we re students . <end>
# Translated: we re students .
# --------------------------------------------------
# Arabic: إذاً هيا بنا نذهب.
# English: <start> well , let s go . <end>
# Translated: well , let s go .
# --------------------------------------------------
# Arabic: يا له من كلب كبير!
# English: <start> what a big dog ! <end>
# Translated: are you talking for him .
# --------------------------------------------------
# Arabic: ماذا عن "توم"؟
# English: <start> what about tom ? <end>
# Translated: what about tom ?
# --------------------------------------------------
# Arabic: ما هو عملك؟
# English: <start> what do you do ? <end>
# Translated: what do you do ?
# --------------------------------------------------
# Arabic: ماذا لو فشلت؟
# English: <start> what if i fail ? <end>
# Translated: what if i say , what if if if you re ?
# --------------------------------------------------
# Arabic: أين هم؟
# English: <start> where are they ? <end>
# Translated: where are they ?
# --------------------------------------------------
# Arabic: أين تقع باريس؟
# English: <start> where is paris ? <end>
# Translated: where is paris ?
# --------------------------------------------------
# Arabic: أين كنت؟
# English: <start> where were you ? <end>
# Translated: where have you been ?
# --------------------------------------------------
# Arabic: من كسر هذا؟
# English: <start> who broke this ? <end>
# Translated: who broke this ?
# --------------------------------------------------
# Arabic: من هذا الصبي؟
# English: <start> who s that boy ? <end>
# Translated: who s that boy ?
# --------------------------------------------------
# Arabic: لم تسأل؟
# English: <start> why do you ask ? <end>
# Translated: why do you ask ?
# --------------------------------------------------
# Arabic: لماذا تسأل؟
# English: <start> why do you ask ? <end>
# Translated: why do you ask ?
# --------------------------------------------------
# Arabic: لماذا هو موجود هنا؟
# English: <start> why is he here ? <end>
# Translated: why s i m at here ?
# --------------------------------------------------
